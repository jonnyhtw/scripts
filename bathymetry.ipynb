# %%
import matplotlib.pyplot as plt
import iris

from pylab import *
import numpy as np
import copy

# %%
bath = iris.load('/home/behrense/_niwa00013p/INPUT/AGRIF_input/NZ02_updated/1_eORCA_R1_bathy_meter_v2.2x.nc')

# %%
bath
# Out:
# [<iris 'Cube' of nav_lon / (degrees) (-- : 329; -- : 419)>,
# <iris 'Cube' of nav_lat / (degrees) (-- : 329; -- : 419)>,
# <iris 'Cube' of bathymetry with isf cavity masked / (m) (-- : 329; -- : 419)>]

# %%
newbath = copy.deepcopy(bath)

# %% [markdown]
# # first region

# %%
xmin = 140
xmax = 150
ymin = -45
ymax = -35

# %%
xmin0 = 144
xmax0 = 146
ymin0 = -38.5
ymax0 = -37

# %%
newbath[2].data[np.where((newbath[0].data > xmin0) & (newbath[0].data < xmax0)
               & (newbath[1].data > ymin0) & (newbath[1].data < ymax0))] = 0

# %%
bath[2].data[bath[2].data == 0] = np.nan

# %%
newbath[2].data[newbath[2].data == 0] = np.nan

# %%
import iris.quickplot as qplt

# %%
fig = plt.figure(figsize=[10,10])

plt.subplot(1, 2, 1)
plt.pcolormesh(bath[0].data, bath[1].data, bath[2].data)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 2, 2)
plt.pcolormesh(newbath[0].data, newbath[1].data, newbath[2].data)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

# %% [markdown]
# # second region

# %%
xmin = 135
xmax = 140
ymin = -35
ymax = -30

# %%
xmin0 = 136.4
xmax0 = 138.5
ymin0 = -34.2
ymax0 = -32

# %%
newbath[2].data[np.where((newbath[0].data > xmin0) & (newbath[0].data < xmax0)
               & (newbath[1].data > ymin0) & (newbath[1].data < ymax0))] = 0

# %%
bath[2].data[bath[2].data == 0] = np.nan

# %%
newbath[2].data[newbath[2].data == 0] = np.nan

# %%
fig = plt.figure()

plt.subplot(1, 2, 1)
plt.pcolormesh(bath[0].data, bath[1].data, bath[2].data)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
#plt.colorbar()

plt.subplot(1, 2, 2)
plt.pcolormesh(newbath[0].data, newbath[1].data, newbath[2].data)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

# %%
newbath[2].data[np.isnan(newbath[2].data)] = 0

# %%
iris.save(newbath, 
          '/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins.nc')

# %% [markdown]
# # global

# %%
str = '/scale_wlg_persistent/filesets/project/niwa00013/behrense/\
INPUT/AGRIF_input/NZ02_updated/bathy_updated.nc'

# %%
str
# Out:
# '/scale_wlg_persistent/filesets/project/niwa00013/behrense/INPUT/AGRIF_input/NZ02_updated/bathy_updated.nc'

# %%
bath = iris.load(str)

# %%
newbath = copy.deepcopy(bath)

# %% [markdown]
# # first region

# %%
xmin = 60
xmax = 80
ymin = 125
ymax = 140

# %%
xmin0 = 144
xmax0 = 146
ymin0 = -38.5
ymax0 = -37

# %%
newbath[2].data[np.where((newbath[0].data > xmin0) & (newbath[0].data < xmax0)
               & (newbath[1].data > ymin0) & (newbath[1].data < ymax0))] = 0

# %%
bath[2].data[bath[2].data == 0] = np.nan

# %%
newbath[2].data[newbath[2].data == 0] = np.nan

# %%
fig = plt.figure()

plt.subplot(1, 2, 1)
qplt.pcolormesh(bath[2])
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])


plt.subplot(1, 2, 2)
qplt.pcolormesh(newbath[2])
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
# Out:
# (125, 140)

# %% [markdown]
# # second region

# %%
xmin = 60
xmax = 80
ymin = 125
ymax = 140

# %%
xmin0 = 136.4
xmax0 = 139
ymin0 = -34.2
ymax0 = -32

# %%
newbath[2].data[np.where((newbath[0].data > xmin0) & (newbath[0].data < xmax0)
               & (newbath[1].data > ymin0) & (newbath[1].data < ymax0))] = 0

# %%
bath[2].data[bath[2].data == 0] = np.nan

# %%
newbath[2].data[newbath[2].data == 0] = np.nan

# %%
import iris.plot as iplt

# %%
fig = plt.figure()

plt.subplot(1, 2, 1)
iplt.pcolormesh(bath[2])
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.title('')

plt.subplot(1, 2, 2)
iplt.pcolormesh(newbath[2])
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])

plt.tight_layout()
plt.title('')
# Out:
# Text(0.5,1,'')

# %%
newbath[2].data[np.isnan(newbath[2].data)] = 0

# %%
iris.save(newbath, 
          '/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/bathy_updated-fixed-basins.nc')

# %% [markdown]
# # Set all bathymetry in AGRIF region which is less than 10m to land

# %%
agrifbath = iris.load('/home/behrense/_niwa00013p/INPUT/AGRIF_input/NZ02_updated/1_eORCA_R1_bathy_meter_v2.2x.nc')

# %%
agriflonmin = np.min(agrifbath[0].data)
agriflonmax = np.max(agrifbath[0].data)
agriflatmin = np.min(agrifbath[1].data)
agriflatmax = np.max(agrifbath[1].data)

# %%
str = '/scale_wlg_persistent/filesets/project/niwa00013/behrense/\
INPUT/AGRIF_input/NZ02_updated/bathy_updated.nc'

# %%
str
# Out:
# '/scale_wlg_persistent/filesets/project/niwa00013/behrense/INPUT/AGRIF_input/NZ02_updated/bathy_updated.nc'

# %%
bath = iris.load(str)

# %%
newbath = copy.deepcopy(bath)

# %%
newbath[2].data[np.where((newbath[0].data > agriflonmin) & (newbath[0].data < agriflonmax)
               & (newbath[1].data > agriflatmin) & (newbath[1].data < agriflatmax) & (newbath[2].data <= 10)) ] = 0

# %%
iris.save(newbath, 
          '/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/\
bathy_updated-10m-in-agrif-region.nc')

# %% [markdown]
# # fix aborted runs by editing bathymetry

# %%
# %%bash
# ncatted -O -a calendar,time_counter,m,c,'360_day' 1_output.abort.nc foo.nc
# Out:
# which: no hsi in (/nesi/nobackup/niwa00013/williamsjh/miniconda2/envs/master/bin:/nesi/nobackup/niwa00013/williamsjh/miniconda2/envs/master/bin:/nesi/nobackup/niwa00013/williamsjh/miniconda2/bin:/nesi/nobackup/niwa00013/williamsjh/miniconda2/condabin:/nesi/nobackup/niwa00013/williamsjh/miniconda2/bin:/opt/nesi/CS500_centos7_skl/NCO/4.7.5-GCC-7.1.0/bin:/opt/nesi/CS500_centos7_skl/GSL/2.4-GCC-7.1.0/bin:/home/williamsjh/bin:/opt/nesi/CS500_centos7_skl/NCVIEW/2.1.8-GCC-7.1.0/bin:/opt/nesi/CS500_centos7_skl/libXpm/3.5.11-GCC-7.1.0/bin:/opt/nesi/CS500_centos7_skl/UDUNITS/2.2.25-GCC-7.1.0/bin:/opt/nesi/CS500_centos7_skl/netCDF/4.6.1-GCC-7.1.0/bin:/opt/nesi/CS500_centos7_skl/cURL/7.56.1-GCC-7.1.0/bin:/opt/nesi/CS500_centos7_skl/HDF5/1.10.1-GCC-7.1.0/bin:/opt/nesi/CS500_centos7_skl/FCM/2019.05.0-GCC-7.1.0/sbin:/opt/nesi/CS500_centos7_skl/FCM/2019.05.0-GCC-7.1.0/bin:/opt/nesi/CS500_centos7_skl/Digest-SHA/6.02-GCC-7.1.0/bin:/opt/nesi/CS500_centos7_skl/Subversion/1.9.7-GCC-7.1.0/bin:/opt/nesi/CS
# ...

# %% [markdown]
# # first region

# %%
abort = iris.load_cube('/home/williamsjh/cylc-run/u-bl000/work/19500101T0000Z/coupled/foo.nc','Zonal Current')
# Out:
# /nesi/nobackup/niwa00013/williamsjh/miniconda2/envs/master/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1304: UserWarning: Ignoring netCDF variable u'soicecov' invalid units u'[0,1]'
#   warnings.warn(msg.encode('ascii', errors='backslashreplace'))
# /nesi/nobackup/niwa00013/williamsjh/miniconda2/envs/master/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1304: UserWarning: Ignoring netCDF variable u'sowaflup' invalid units u'Kg/m2/S'
#   warnings.warn(msg.encode('ascii', errors='backslashreplace'))
# /nesi/nobackup/niwa00013/williamsjh/miniconda2/envs/master/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1304: UserWarning: Ignoring netCDF variable u'vosaline' invalid units u'PSU'
#   warnings.warn(msg.encode('ascii', errors='backslashreplace'))

# %%
bath=iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins.nc')

# %%
#bath = iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix.nc')

# %%
newbath=copy.deepcopy(bath)

# %%
agriflonmin = 194.3
agriflonmax = 194.8
agriflatmin = -56.5
agriflatmax = -56.3

# %%
#agriflonmin = 193
#agriflonmax = 196
#agriflatmin = -57
#agriflatmax = -55

# %%
newbath=copy.deepcopy(bath)

newbath[2].data[np.where((newbath[0].data > agriflonmin) & (newbath[0].data < agriflonmax)
               & (newbath[1].data > agriflatmin) & (newbath[1].data < agriflatmax))] = 5e3

# %%
newbath=copy.deepcopy(bath)

newbath[2].data[np.where((newbath[0].data > agriflonmin) & (newbath[0].data < agriflonmax)
               & (newbath[1].data > agriflatmin) & (newbath[1].data < agriflatmax))] = 5.4e3
fig = plt.figure(figsize=[10,10])

xmin=300
xmax=320
ymin=30
ymax=50

plt.subplot(1, 3, 1)
qplt.pcolormesh(bath[2],vmin=5e3,vmax=6e3)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 2)
qplt.pcolormesh(newbath[2],vmin=5e3,vmax=6e3)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 3)
qplt.pcolormesh(abort[0][0])
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()




plt.tight_layout()

# %%
iris.save(newbath, 
          '/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix.nc')

# %% [markdown]
# # second region

# %%
abort = iris.load_cube('/home/williamsjh/cylc-run/u-bl000/work/19500101T0000Z/coupled/bar.nc','Zonal Current')

# %%
bath=iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix.nc')

# %%
#bath = iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix.nc')

# %%
newbath=copy.deepcopy(bath)

# %%
#agriflonmin = 193
#agriflonmax = 196
#agriflatmin = -57
#agriflatmax = -55

# %%
newbath=copy.deepcopy(bath)

agriflonmin = 201.7
agriflonmax = 202.8
agriflatmin = -51.7
agriflatmax = -51.2

newbath[2].data[np.where((newbath[0].data > agriflonmin) & (newbath[0].data < agriflonmax)
              & (newbath[1].data > agriflatmin) & (newbath[1].data < agriflatmax))] = 5e3

fig = plt.figure(figsize=[10,10])

xmin=340
xmax=355
ymin=75
ymax=85

plt.subplot(1, 3, 1)
qplt.pcolormesh(bath[2],vmin=5e3,vmax=6e3,cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 2)
qplt.pcolormesh(newbath[2],vmin=5e3,vmax=6e3,cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 3)
qplt.pcolormesh(abort[0][0],cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()




plt.tight_layout()

# %%
iris.save(newbath, 
          '/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix2.nc')

# %%
agriflonmin = 201.7
agriflonmax = 203
agriflatmin = -51.9
agriflatmax = -51.2

# %% [markdown]
# # third region

# %%
abort = iris.load_cube('/home/williamsjh/cylc-run/u-bl000/work/19500101T0000Z/coupled/baz.nc','Zonal Current')

# %%
bath=iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix.nc')

# %%
#bath = iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix.nc')

# %%
newbath=copy.deepcopy(bath)

# %%
newbath=copy.deepcopy(bath)

agriflonmin = 201.7
agriflonmax = 203
agriflatmin = -51.9
agriflatmax = -51.2

newbath[2].data[np.where((newbath[0].data > agriflonmin) & (newbath[0].data < agriflonmax)
              & (newbath[1].data > agriflatmin) & (newbath[1].data < agriflatmax))] = 5e3

fig = plt.figure(figsize=[10,10])

xmin=340
xmax=355
ymin=75
ymax=85

plt.subplot(1, 3, 1)
qplt.pcolormesh(bath[2],vmin=5e3,vmax=6e3,cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 2)
qplt.pcolormesh(newbath[2],vmin=5e3,vmax=6e3,cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 3)
qplt.pcolormesh(abort[0][0],cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()




plt.tight_layout()

# %%
iris.save(newbath, 
          '/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix3.nc')

# %% [markdown]
# # fourth region

# %%
abort = iris.load_cube('/home/williamsjh/cylc-run/u-bl000/work/19500101T0000Z/coupled/qux.nc','Zonal Current')

# %%
bath=iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix.nc')

# %%
#bath = iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix.nc')

# %%
newbath=copy.deepcopy(bath)

# %%
newbath=copy.deepcopy(bath)

agriflonmin = 201.8
agriflonmax = 203.3
agriflatmin = -51.9
agriflatmax = -51.2

newbath[2].data[np.where((newbath[0].data > agriflonmin) & (newbath[0].data < agriflonmax)
              & (newbath[1].data > agriflatmin) & (newbath[1].data < agriflatmax))] = 5e3

fig = plt.figure(figsize=[10,10])

xmin=340
xmax=355
ymin=72
ymax=85

plt.subplot(1, 3, 1)
qplt.pcolormesh(bath[2],vmin=5e3,vmax=6e3,cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 2)
qplt.pcolormesh(newbath[2],vmin=5e3,vmax=6e3,cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 3)
qplt.pcolormesh(abort[0][0],cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()




plt.tight_layout()

# %%
iris.save(newbath, 
          '/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix4.nc')

# %% [markdown]
# # fifth region

# %%
abort = iris.load_cube('/home/williamsjh/cylc-run/u-bl000/work/19500101T0000Z/coupled/quz.nc','Zonal Current')

# %%
bath=iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix.nc')

# %%
bath=iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix4.nc')

# %%
newbath=copy.deepcopy(bath)

# %%
newbath=copy.deepcopy(bath)

agriflonmin = 201.8
agriflonmax = 203.3
agriflatmin = -51.9
agriflatmax = -51.2

newbath[2].data[np.where((newbath[0].data > agriflonmin) & (newbath[0].data < agriflonmax)
              & (newbath[1].data > agriflatmin) & (newbath[1].data < agriflatmax))] = 5e3

fig = plt.figure(figsize=[10,10])

xmin=340
xmax=355
ymin=72
ymax=85

plt.subplot(1, 3, 1)
qplt.pcolormesh(bath[2],vmin=5e3,vmax=6e3,cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 2)
qplt.pcolormesh(newbath[2],vmin=5e3,vmax=6e3,cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()

plt.subplot(1, 3, 3)
qplt.pcolormesh(abort[0][0],cmap='viridis')
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.colorbar()




plt.tight_layout()

# %%
iris.save(newbath, 
          '/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins-stability-fix4.nc')

# %% [markdown]
# # reduce bottom levels of 1950 AGRIF restart to rest linearly

# %%
agrifbath = iris.load('/home/behrense/_niwa00013p/INPUT/AGRIF_input/NZ02_updated/1_eORCA_R1_bathy_meter_v2.2x.nc')

# %%
agrifbath
# Out:
# [<iris 'Cube' of nav_lon / (degrees) (-- : 329; -- : 419)>,
# <iris 'Cube' of nav_lat / (degrees) (-- : 329; -- : 419)>,
# <iris 'Cube' of bathymetry with isf cavity masked / (m) (-- : 329; -- : 419)>]

# %%
restart = iris.load('/home/behrense/_niwa00013p/INPUT/AGRIF_input/NZ02_updated/restart_modified/1_bb075o_19500101_restart.nc')

# %%
for i in np.arange(len(restart)):
    print i, restart[i].var_name
    restart[i] = iris.cube.Cube(restart[i].data.squeeze(),long_name=restart[i].var_name)
# Out:
# 0 vb
# 1 en
# 2 time_counter
# 3 vn
# 4 tn
# 5 gcx
# 6 tb
# 7 nav_lat
# 8 gcxb
# 9 rhop
# 10 nav_lon
# 11 nav_lev
# 12 hdivb
# 13 sshb
# 14 sshn
# 15 hdivn
# 16 un
# 17 sn
# 18 rotn
# 19 sb
# 20 rotb
# 21 ub

# %%
restart[0]
# Out:
# <iris 'Cube' of vb / (unknown) (-- : 75; -- : 329; -- : 419)>

# %%
restart[3]
# Out:
# <iris 'Cube' of vn / (unknown) (-- : 75; -- : 329; -- : 419)>

# %%
restart[21]
# Out:
# <iris 'Cube' of ub / (unknown) (-- : 75; -- : 329; -- : 419)>

# %%
restart[16]
# Out:
# <iris 'Cube' of un / (unknown) (-- : 75; -- : 329; -- : 419)>

# %%
these=0

# %%
restart[0].data[these:] = 0.

# %%
restart[3].data[these:] = 0.

# %%
restart[21].data[these:] = 0.

# %%
restart[16].data[these:] = 0.

# %%
iris.save(restart,'/nesi/project/niwa00013/williamsjh/NZESM-AGRIF-start-dump/1_bb075o_19500101_restart_base0.nc')

# %%
restart = iris.load('/home/behrense/_niwa00013p/INPUT/AGRIF_input/NZ02_updated/restart_modified/1_bb075o_19500101_restart.nc')

# %%
bath = iris.load('/scale_wlg_persistent/filesets/project/niwa00013/behrense/INPUT/AGRIF_input/NZ02_updated/bathy_updated.nc')

# %%
agrifbath = iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins.nc')

# %%
print np.min(agrifbath[0].data)
print np.max(agrifbath[0].data)
print np.min(agrifbath[1].data)
print np.max(agrifbath[1].data)
# Out:
# 132.7
# 216.3
# -60.17149
# -10.749452

# %%
bath
# Out:
# [<iris 'Cube' of nav_lon / (degrees) (-- : 332; -- : 362)>,
# <iris 'Cube' of nav_lat / (degrees) (-- : 332; -- : 362)>,
# <iris 'Cube' of bathymetry with isf cavity masked / (m) (-- : 332; -- : 362)>]

# %%
plt.subplot(1,2,1)
qplt.pcolormesh(bath[2])

plt.subplot(1,2,2)
qplt.pcolormesh(agrifbath[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4f4c84831f2f> in <module>()
#       1 plt.subplot(1,2,1)
# ----> 2 qplt.pcolormesh(bath[2])
#       3
#       4 plt.subplot(1,2,2)
#       5 qplt.pcolormesh(agrifbath[2])
#
# NameError: name 'qplt' is not defined

# %%
#agrifbath = iris.load('/home/behrense/_niwa00013p/INPUT/AGRIF_input/NZ02_updated/1_eORCA_R1_bathy_meter_v2.2x.nc')
agrifbath = iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins.nc')
newagrifbath = copy.deepcopy(agrifbath)

maxdiff = 1e1

boundary = 50


for i in arange(boundary,shape(agrifbath[2].data)[0]-boundary):
    for j in arange(boundary,shape(agrifbath[2].data)[1]-boundary):
        foo = abs( agrifbath[2].data[i][j] - agrifbath[2].data[i-1][j] )
        bar = abs( agrifbath[2].data[i][j] - agrifbath[2].data[i][j-1] )
        if (foo > maxdiff) and (agrifbath[2].data[i-1][j] != agrifbath[2].data[i-2][j]):
            newagrifbath[2].data[i][j] = np.mean([agrifbath[2].data[i][j], agrifbath[2].data[i-1][j]])
        if (bar > maxdiff) and (agrifbath[2].data[i][j-1] != agrifbath[2].data[i][j-2]):
            newagrifbath[2].data[i][j] = np.mean([agrifbath[2].data[i][j], agrifbath[2].data[i][j-1]])

# %%
iris.save(newagrifbath,'/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_bathy_updated-fixed-basins-smoothed.nc')
# Out:
# /nesi/nobackup/niwa00013/williamsjh/miniconda2/envs/master/lib/python2.7/site-packages/iris/fileformats/netcdf.py:2281: IrisDeprecation: NetCDF default saving behaviour currently assigns the outermost dimensions to unlimited. This behaviour is to be deprecated, in favour of no automatic assignment. To switch to the new behaviour, set iris.FUTURE.netcdf_no_unlimited to True.
#   warn_deprecated(msg)

# %%
from scipy import ndimage
import iris

# %%
print iris.__version__
# Out:
# 1.9.2

# %%
agrifbath = iris.load('/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_eORCA_R1_bathy_meter_v2.2x-fixed-basins.nc')
newagrifbath = copy.deepcopy(agrifbath)

# %%
import iris.quickplot as qplt

# %%
import matplotlib.pyplot as pl
import numpy as np
import scipy as sp
import scipy.ndimage

# %%
fig = plt.figure(figsize=[10,10])

plt.subplot(2,2,1)
plt.pcolormesh(agrifbath[2].data)

plt.subplot(2,2,2)
plt.pcolormesh(sp.ndimage.filters.gaussian_filter(agrifbath[2].data, [1, 1], mode='constant'))

plt.subplot(2,2,3)
plt.pcolormesh(sp.ndimage.filters.gaussian_filter(agrifbath[2].data, [2, 2], mode='constant'))

plt.subplot(2,2,4)
plt.pcolormesh(sp.ndimage.filters.gaussian_filter(agrifbath[2].data, [3, 3], mode='constant'))

# %%
newagrifbath[2].data = sp.ndimage.filters.gaussian_filter(agrifbath[2].data, [1, 1], mode='constant')

# %%
newagrifbath[2].data[np.where(agrifbath[2].data == 0)] = 0

# %%
iris.save(newagrifbath,'/nesi/project/niwa00013/williamsjh/NZESM-edited-bathymetry/1_bathy_updated-fixed-basins-smoothed.nc')

# %%
tsinput = iris.load('/scale_wlg_persistent/filesets/project/niwa00013/behrense/INPUT/AGRIF_input/NZ02_updated/1_TS_input_fillmiss3.nc')

# %%
tsinput
# Out:
# [<iris 'Cube' of longitude / (degrees) (-- : 329; -- : 419)>,
# <iris 'Cube' of temperature / (kelvin) (-- : 12; depth of cell centres on t grid: 75; -- : 329; -- : 419)>,
# <iris 'Cube' of latitude / (degrees) (-- : 329; -- : 419)>,
# <iris 'Cube' of salinity / (unknown) (-- : 12; depth of cell centres on t grid: 75; -- : 329; -- : 419)>]

# %%
restart = iris.load('/home/behrense/_niwa00013p/INPUT/AGRIF_input/NZ02_updated/restart_modified/1_bb075o_19500101_restart.nc')

# %%
restart
# Out:
# [<iris 'Cube' of vb / (1) (-- : 1; -- : 75; -- : 329; -- : 419)>,
# <iris 'Cube' of en / (1) (-- : 1; -- : 75; -- : 329; -- : 419)>,
# <iris 'Cube' of time_counter / (1) (-- : 1)>,
# <iris 'Cube' of vn / (1) (-- : 1; -- : 75; -- : 329; -- : 419)>,
# <iris 'Cube' of tn / (1) (-- : 1; -- : 75; -- : 329; -- : 419)>,
# <iris 'Cube' of gcx / (1) (-- : 1; -- : 329; -- : 419)>,
# <iris 'Cube' of tb / (1) (-- : 1; -- : 75; -- : 329; -- : 419)>,
# <iris 'Cube' of nav_lat / (1) (-- : 329; -- : 419)>,
# <iris 'Cube' of gcxb / (1) (-- : 1; -- : 329; -- : 419)>,
# <iris 'Cube' of rhop / (1) (-- : 1; -- : 75; -- : 329; -- : 419)>,
# <iris 'Cube' of nav_lon / (1) (-- : 329; -- : 419)>,
# <iris 'Cube' of nav_lev / (1) (-- : 75)>,
# <iris 'Cube' of hdivb / (1) (-- : 1; -- : 75; -- : 329; -- : 419)>,
# <iris 'Cube' of sshb / (1) (-- : 1; -- : 329; -- : 419)>,
# <iris 'Cube' of sshn / (1) (-- : 1; -- : 329; -- : 419)>,
# <iris 'Cube' of hdivn / (1) (-- : 1; -- : 75; -- : 329; -- : 419)>,
# ...

# %%
import netCDF4
tsinput = netCDF4.Dataset('/nesi/project/niwa00013/williamsjh/NZESM-AGRIF-start-dump/1_TS_input_fillmiss3-from-start-dump.nc','r+')

# %%
tsinput.variables['temperature'][:][0].shape
# Out:
# (75, 329, 419)

# %%
import netCDF4
restart = netCDF4.Dataset('/nesi/project/niwa00013/williamsjh/NZESM-AGRIF-start-dump/1_bb075o_19500101_restart.nc','r+')

# %%
restart.variables['tb'][:][0].shape
# Out:
# (75, 329, 419)

# %%
restart.variables['temperature'][:][0] = copy.copy(tsinput.variables['tb'][:][0])

# %%
newrestart = netCDF4.Dataset('/nesi/project/niwa00013/williamsjh/NZESM-AGRIF-start-dump/1_TS_input_fillmiss3-from-start-dump.nc','w')

# %%
newrestart = copy.deepcopy(restart)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-326-bd2e121f0e38> in <module>()
# ----> 1 newrestart = copy.deepcopy(restart)
#
# /nesi/nobackup/niwa00013/williamsjh/miniconda2/envs/master/lib/python2.7/copy.pyc in deepcopy(x, memo, _nil)
#     180                     reductor = getattr(x, "__reduce_ex__", None)
#     181                     if reductor:
# --> 182                         rv = reductor(2)
#     183                     else:
#     184                         reductor = getattr(x, "__reduce__", None)
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__reduce__()
#
# NotImplementedError: Dataset is not picklable

# %%
newrestart
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /nesi/nobackup/niwa00013/williamsjh/miniconda2/envs/master/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /nesi/nobackup/niwa00013/williamsjh/miniconda2/envs/master/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     401                         if cls is not object \
#     402                                 and callable(cls.__dict__.get('__repr__')):
# --> 403                             return _repr_pprint(obj, self, cycle)
#     404
#     405             return _default_pprint(obj, self, cycle)
#
# ...

# %%
newrestart.close()
